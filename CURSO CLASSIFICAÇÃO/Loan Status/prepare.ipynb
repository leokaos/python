# %%
import pandas as pd

# %%
dados = pd.read_csv("loan_data.csv")

dados = dados.drop("Loan_ID", axis=1)

# %%
dados['Loan_Status'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Loan_Status'>

# %%
dados.columns[dados.isna().any()].tolist()
# Out:
# ['Gender', 'Dependents', 'Self_Employed', 'Loan_Amount_Term', 'Credit_History']

# %%
dados['Gender'].unique()
# Out:
# array(['Male', 'Female', nan], dtype=object)

# %%
# using sklearn-pandas package
from sklearn_pandas import CategoricalImputer
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[45], line 2
#       1 # using sklearn-pandas package
# ----> 2 from sklearn_pandas import CategoricalImputer
#
# ImportError: cannot import name 'CategoricalImputer' from 'sklearn_pandas' (c:\Users\leoka\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn_pandas\__init__.py)
