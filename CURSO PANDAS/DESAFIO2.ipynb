# %%
import pandas as pd

dados = pd.read_csv('alunos.csv')

dados.shape
# Out:
# (18, 4)

# %%
dados.isnull().sum()
# Out:
# Nome        0
# Idade       0
# Notas       6
# Aprovado    0
# dtype: int64

# %%
dados.fillna(0, inplace=True)

# %%
dados.drop(index=dados.query("Nome == 'Alice' | Nome == 'Carlos'").index, inplace=True)
dados.shape
# Out:
# (16, 4)

# %%
dados[dados['Aprovado'] == True].to_csv('alunos_aprovados.csv', index=False)

# %%
dados.Notas.replace(7.0, 8.0, inplace=True)
dados
# Out:
#          Nome  Idade  Notas  Aprovado
# 0         Ary     20    7.5      True
# 1         Ana     18    0.0     False
# 2       Cátia     27    2.5     False
# 3       Denis     18    5.0     False
# 4        Beto     21   10.0      True
# 5       Bruna     23    0.0     False
# 6        Dara     21    8.0      True
# 9       Vitor     28    0.0     False
# 10     Daniel     21    0.0     False
# 11       Igor     24    4.5     False
# 12  Sthefanie     26    9.5      True
# 13      Mirla     25    9.0      True
# 14      Paulo     37    0.0     False
# 15     Mylena     29    8.0      True
# 16      Lucas     33    0.0     False
# 17      Nadia     34    8.0      True
