# %%
dicionario = {'chave_1':1,
              'chave_2':2}
dicionario
# Out:
# {'chave_1': 1, 'chave_2': 2}

# %%
cadastro = {'matricula': 2000168933,
            'dia_cadastro': 25,
            'mes_cadastro': 10,
            'turma': '2E'}
cadastro
# Out:
# {'matricula': 2000168933,
#  'dia_cadastro': 25,
#  'mes_cadastro': 10,
#  'turma': '2E'}
